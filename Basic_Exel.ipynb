# %% [markdown]
# #
# 1 - Explain the difference between Relative , Absolute and Mixed Cell Referencing.
#
# - Relative references (A1) change when copied, adjusting to the new cell's position; Absolute references ($A$1) stay fixed, locking both row and column with dollar signs; and Mixed references ($A1 or A$1) lock either the column or the row, but not both, allowing one part to change while the other stays constant
#
# 2 - rite a formula to calculate the total sales of Car and Bicyle only
#
# - the formula is =sum(500000+10500)
#
# 3 - Using the data below, write a formula to calculate the average sales of items priced above 100 but less than
# 300:
#
# - the formula is =AVERAGEif(90-250,"<100,>300")
#
# 4 - Count how many customer names are recorded
#
# - 50
#
# 5 - Calculate the Total Sales for each row using a formula.
#
# - Formula is =$E2*$F2
#
# 6 - Calculate the total sales of Notebooks in the North region only.
#
# -
#
# 7 - Create a column chart showing total sales by product.
#
# - TO create tyhe column chart first select the column sales and product then go to insert then recomendent chart then select column chart
#
# 8 - nsert a line chart showing daily sales trend.
#
# - TO create tyhe Line chart first select the column sales then go to insert then recomendent chart then select Line chart
